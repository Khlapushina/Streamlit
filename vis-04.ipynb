# %% [markdown]
# # Чаевые в ресторане

# %% [markdown]
# Это задание основано на туториале Seaborn. Используйте здесь эту библиотеку.
#
# ### Шаг 1. Импортируем библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Шаг 2. Прочитаем датасет в переменную tips

# %%
path = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv'
# path = '../learning/datasets/tips.csv'

# %%
tips1 = pd.read_csv(path)
tips1.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %% [markdown]
# ### Шаг 3.  У нас есть колонка, дублирующая индекс. Как вы думаете, откуда она получилась?

# %% [markdown]
# Нашла предположение в интернете, что файл мог быть сохранен с индексом по умолчанию

# %% [markdown]
# ответ тут

# %% [markdown]
# ### Прочитайте датасет еще раз, автоматически взяв первую колонку как индекс.

# %%
tips = pd.read_csv(path, index_col=0)
tips.head(5)
# Out:
#              tip     sex smoker  day    time  size
# total_bill
# 16.99       1.01  Female     No  Sun  Dinner     2
# 10.34       1.66    Male     No  Sun  Dinner     3
# 21.01       3.50    Male     No  Sun  Dinner     3
# 23.68       3.31    Male     No  Sun  Dinner     2
# 24.59       3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Шаг 4. Нарисуйте гистограмму total_bill

# %%
tips1.hist(column='total_bill')
# Out:
# array([[<Axes: title={'center': 'total_bill'}>]], dtype=object)

# %% [markdown]
# ### Шаг 5. Нарисуйте scatterplot, показывающий связь между total_bill and tip

# %%
df_for_scatter = tips.sort_index()
df_for_scatter.head(5)
# Out:
#              tip     sex smoker   day    time  size
# total_bill
# 3.07        1.00  Female    Yes   Sat  Dinner     1
# 5.75        1.00  Female    Yes   Fri  Dinner     2
# 7.25        1.00  Female     No   Sat  Dinner     1
# 7.25        5.15    Male    Yes   Sun  Dinner     2
# 7.51        2.00    Male     No  Thur   Lunch     2

# %%
x_bill = df_for_scatter.index
y_tip = df_for_scatter['tip']

fig04_5 = plt.figure(figsize = (15, 7),dpi=200)
plt.scatter(x_bill, y_tip)
plt.xlabel('total_bill')
plt.ylabel('tip');
fig04_5.savefig('my_figure04_5')

# %% [markdown]
# ### Шаг 7. Нарисуйте 1 график, связывающий total_bill, tip, и size
# #### Подсказка: это одна функция

# %%
df04_7_total_bill = tips1.groupby('size', as_index=False)['total_bill'].mean()
df04_7_total_bill
df04_7_tip = tips.groupby('size', as_index=False)['tip'].mean()
df04_7_tip
# Out:
#    size       tip
# 0     1  1.437500
# 1     2  2.582308
# 2     3  3.393158
# 3     4  4.135405
# 4     5  4.028000
# 5     6  5.225000

# %%
fig04_7 = plt.figure(figsize=(15, 5), dpi=200)
plt.plot(df04_7_total_bill['total_bill'], df04_7_tip['tip'])
plt.xlabel('Total Bill/Size')
plt.ylabel('Tip/Size')
fig04_7.savefig('my_figure04_7');

# %% [markdown]
# ### Шаг 8. Покажите связь между днем недели и размером счета

# %%
df04_8 = tips1.groupby('day', as_index=False)['total_bill'].mean()
fig04_8 = plt.figure(figsize=(10, 5), dpi=200)
plt.bar(df04_8['day'], df04_8['total_bill'], width=0.3)
plt.xlabel('Day')
plt.ylabel('Total bill')
fig04_8.savefig('my_figure04_8');

# %% [markdown]
# ### Шаг 9. Нарисуйте scatter plot с днем недели по оси y, чаевыми по оси x, и цветом по полу

# %%
tips_male = tips[tips['sex']=='Male']
tips_female = tips[tips['sex']=='Female']

# %%
fig04_9 = plt.figure(figsize=(20, 5), dpi=200)
plt.scatter(tips_male['tip'], tips_male['day'], label = 'Male')
plt.scatter(tips_female['tip'], tips_female['day'], c = 'red', label = 'Female')
plt.xlabel('Tips')
plt.ylabel('Days')
plt.legend()
fig04_9.savefig('my_figurre04_9');

# %% [markdown]
# ### Шаг 10. Нарисуйте box plot c суммой всех счетов за каждый день, разбивая по time (Dinner/Lunch)

# %%
tips1.boxplot(column=['total_bill'], by='day');

# %%
sns.boxplot(x='day', y='total_bill', hue='time', data=tips1);
# Out:
# /home/larisa/miniforge3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/larisa/miniforge3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/larisa/miniforge3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ### Шаг 11. Нарисуйте 2 гистограммы чаевых на обед и ланч. Расположите их рядом по горизонтали.

# %%
df_dinner = tips[tips['time']=='Dinner']
df_lunch = tips[tips['time']=='Lunch']
fig04_11 = plt.figure()
sns.histplot(df_dinner['tip'], alpha=0.5, label='Dinner tips')
sns.histplot(df_lunch['tip'], alpha=0.5, label='Lunch tips')
plt.legend()
fig04_11.savefig('my_figure04_11');
# Out:
# /home/larisa/miniforge3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/larisa/miniforge3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/larisa/miniforge3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ### Шаг 12. Нарисуйте 2 scatterplots (для мужчин и женщин), показав связь размера счета и чаевых, дополнительно разбив по курящим/некурящим. Расположите их по горизонтали.

# %%
dfm_12 = tips1[tips1['sex']=='Male']
dff_12 = tips1[tips1['sex']=='Female']
dfm_12_0 = dfm_12[dfm_12['smoker']=='No']
dfm_12_1 = dfm_12[dfm_12['smoker']=='Yes']
dff_12_0 = dff_12[dff_12['smoker']=='No']
dff_12_1 = dff_12[dff_12['smoker']=='Yes']

# %%
fig04_12 = plt.figure(figsize=(20, 5))
plt.subplot(1, 2, 1)
plt.title('Male')
plt.scatter(dfm_12_0['total_bill'], dfm_12_0['tip'], c='lightblue', label = 'No smoker')
plt.scatter(dfm_12_1['total_bill'], dfm_12_1['tip'], c='grey', label = 'Smoker')
plt.xlabel('Total bill')
plt.ylabel('Tips')
plt.legend()
plt.subplot(1, 2, 2)
plt.title('Female')
plt.scatter(dff_12_0['total_bill'], dff_12_0['tip'], c='lightblue', label = 'No smoker')
plt.scatter(dff_12_1['total_bill'], dff_12_1['tip'], c='grey', label = 'Smoker')
plt.xlabel('Total bill')
plt.ylabel('Tips')
plt.legend()
fig04_12.savefig('my_figure04_12');

# %% [markdown]
# ### БОНУС: Задайте свой вопрос и ответьте на него с помощью графика.
